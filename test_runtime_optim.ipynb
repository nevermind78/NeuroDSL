# %% [markdown]
# # Run NeuroDSL Runtime Optimization Tests
# This notebook activates the NeuroDSL project and runs `test/test_runtime_optimizations.jl`.

# %%
using Pkg
Pkg.activate(".")
using NeuroDSL
println("Project activated and NeuroDSL loaded.")
# Out:
#   Activating project at `c:\Users\Nevermind\Desktop\NeuroDSL`
# Project activated and NeuroDSL loaded.

# %% [markdown]
# ## Run the runtime optimization test file
# The following cell executes the NeuroDSL runtime optimization test script from the repository root.

# %%
include("test/test_runtime_optimizations.jl")
# Out:
# [ Info: CheckpointSchedule: 3 checkpoints, 1 recomputables
# Test Summary:         | Pass  Total   Time
# Runtime optimizations |   22     22  53.7s
# ┌ Warning: Loss scale overflow détecté → scale=16.0
# └ @ NeuroDSL c:\Users\Nevermind\Desktop\NeuroDSL\src\mixed_precision.jl:73
# ...
